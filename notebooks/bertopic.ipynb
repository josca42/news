# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups
 
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2913/1338572796.py in <module>
# ----> 1 from bertopic import BERTopic
#       2 from sklearn.datasets import fetch_20newsgroups
#       3
#       4 docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
#
# ModuleNotFoundError: No module named 'bertopic'

# %%
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2913/3121127374.py in <module>
# ----> 1 from sentence_transformers import SentenceTransformer
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
import

# %%
embedding_model = SentenceTransformer("distiluse-base-multilingual-cased-v2")

# %%
embedding = embedding_model.encode(docs[1])

# %%
topic_model = BERTopic(embedding_model="distiluse-base-multilingual-cased-v2", verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 690/690 [00:00<00:00, 324kB/s]
# Downloading: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2.38k/2.38k [00:00<00:00, 1.25MB/s]
# ...
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 341/341 [00:00<00:00, 149kB/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 539M/539M [00:08<00:00, 60.5MB/s]
# Downloading: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 53.0/53.0 [00:00<00:00, 27.2kB/s]
# ...

# %%
probs[:20]
# Out:
# array([0.        , 0.78144975, 0.63182652, 0.        , 1.        ,
#        0.        , 0.4174953 , 0.25773792, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.078776  , 0.596313  ,
#        0.21686718, 0.        , 0.99962224, 0.89214615, 0.        ])

# %%
topics[:20]
# Out:
# [-1, 22, 0, -1, 8, -1, 56, 13, -1, -1, -1, -1, -1, 87, 0, 18, -1, 5, 48, -1]

# %%
topic_model.

# %%
len(np.unique(topics))
# Out:
# 117

# %%
#topic_model.topic_embeddings

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_hierarchy(top_n_topics=50)

# %%
np.unique(topics).shape
# Out:
# (180,)

# %%
topic_model.visualize_barchart(top_n_topics=5)

# %%
topic_model.visualize_topics()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 topic_model.visualize_topics()
#
# File ~/src/miniconda/envs/nlp/lib/python3.9/site-packages/bertopic/_bertopic.py:559, in BERTopic.visualize_topics(self)
#     557 check_is_fitted(self)
#     558 if not _HAS_VIZ:
# --> 559     raise ModuleNotFoundError(f"In order to use this function you'll need to install "
#     560                               f"additional dependencies;\npip install bertopic[visualization]")
#     562 # Extract topic words and their frequencies
#     563 topic_list = sorted(list(self.topics.keys()))
#
# ModuleNotFoundError: In order to use this function you'll need to install additional dependencies;
# pip install bertopic[visualization]

# %%
import bertopic

# %%
bertopic.__version__
# Out:
# '0.4.3'

# %%
2+2
# Out:
# 4
